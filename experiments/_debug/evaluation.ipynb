# %%
import pandas
import seaborn

# %%
tracking: pandas.DataFrame = pandas.read_csv("train.tracking.csv")
tracking
# Out:
#      n  loss_train_discriminator  loss_test_generator  loss_train_generator  \
# 0    1                  0.765625             0.425781              0.395752
# 1    2                  0.644043             0.527344              0.398682
# 2    3                  0.590820             0.451172              0.413330
# 3    4                  0.581055             0.431641              0.402100
# 4    5                  0.576660             0.388672              0.410889
# 5    6                  0.573730             0.447266              0.400391
# 6    7                  0.568359             0.375000              0.413818
# 7    8                  0.567383             0.412109              0.394531
# 8    9                  0.556641             0.406250              0.415527
# 9   10                  0.574707             0.398438              0.393066
# 10  11                  0.556152             0.429688              0.407471
# ...

# %%
tracking_wide = tracking.melt(
    id_vars=["n"],
    value_vars=[
        "loss_train_discriminator",
        "loss_test_generator",
        "loss_train_generator",
        "loss_test_discriminator",
    ],
)
seaborn.lineplot(tracking_wide, x="n", y="value", hue="variable")
# Out:
# <Axes: xlabel='n', ylabel='value'>

# %%
pandas.read_csv("predictions.before.csv").head(n=20)
# Out:
#                                          instructions  \
# 0   In the face of Russian terror, the Ukrainian p...
# 1   Nearly 2 years ago, President Biden marked the...
# 2                         Abortion IS NOT healthcare.
# 3   By indicting Biden’s most formidable political...
# 4   Today marks 11 straight days of record-breakin...
# 5   Pray for President Trump.\nPray for our countr...
# 6   I commend President Biden as Commander in Chie...
# 7   Here’s an idea: how about a primetime special ...
# 8   The House Oversight Committee has subpoenaed f...
# 9   AG Merrick Garland is now appointing a special...
# 10  I want to wish all the Mothers in the world a ...
# 11  Hillary Clinton used a hammer to destroy evide...
# 12         America is FALLING APART under Joe Biden!!
# 13  Should the Oversight and Accountability Commit...
# 14  I'm honored that my Republican colleagues have...
# 15  You ready for a radical idea? Here we go. You ...
# ...

# %%
pandas.read_csv("predictions.after.csv").head(n=20)
# Out:
#                                          instructions  \
# 0   Today marks 11 straight days of record-breakin...
# 1   It is sad to see leading Democrats including s...
# 2   The lawless tyrants at the DOJ will now be ind...
# 3   Tonight I'm PROUD to announce that I've been n...
# 4   Why do you think the Biden administration is f...
# 5   You ready for a radical idea? Here we go. You ...
# 6   I want to wish all the Mothers in the world a ...
# 7   I'm honored that my Republican colleagues have...
# 8   Pray for President Trump.\nPray for our countr...
# 9   Would we have ever even known about the Chines...
# 10  Just a reminder: \n\nThe FBI raided Barron Tru...
# 11         Biden’s war on Christianity needs to END!!
# 12                          TRUMP DID NOTHING WRONG!!
# 13  When it comes to Donald Trump, the New York le...
# 14  The violence in Brazil is not the way to achie...
# 15  Sickened and horrified about another episode o...
# ...
